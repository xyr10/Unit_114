# %%
# python list:

mylist = [1, 2, 3, 4]

help(mylist)
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...

# %%
class SinglyLinkedList:
    class __Node:
        def __init__(self, data):
            self.data = data
            self.next = None
            
    def __init__(self):
        self.head = None
        
    def append(self, value):
        new_node = self.__Node(value)
        if not self.head:                      # state 1: when the list is empty
            self.head = new_node
        else:
            current = self.head                # state 2: when there is only one node and ...
            while current.next:                # state 3: when there is more than one neode in our list.
                current = current.next
            current.next = new_node
        
    def __str__(self):
        out = "["
        current = self.head
        if current:
            out += "%s" % current.data
            current = current.next
            while current:
                out += ", %s" % current.data
                current = current.next
        out += "]"
        return out
    
    def insert(self, index, value):
        # current = self.head
        # prev = None
        # while current and index != counter:
        #   prev = current
        #   current = current.next
        #   counter += 1    (what happens if we reached the while loop and index continues to be none?)
        #   else we'll be appending at the end of the list
        
        # Objective: Insert object before index.
        # Define the initial value
        # Define the initial index 
        # if counter=0, then new_node=self.head
        # Define the object to be inserted
        # state 1: when the list is empty
        # state 2: when there is only one node and 
        # current = current.next
        # state 3: when there is more than one node
        
        
        
        new_node = self.__Node
        current = self.head
        # 

    
    def remove(self, value):
        pass
    
    def index(self, value):
        # return first index of value or ValueError if not present
        current = self.head
        counter = 0
        found = False
        if current:                               # shorthand for if current !=None
            while current.next and not found:
                if current.data == value:
                    found = True
                    break
                counter += 1
                current = current.next
        if found:
            return counter
        raise ValueError( "Value not found" )

# %%
sll = SinglyLinkedList()
python_list = []

print("Empty lists:")
print(sll)
print(python_list)

print("Lists with one element:")
sll.append(1)
print(sll)
python_list.append(1)
print(python_list)

print("Lists with more than one element:")
for number in range(2, 5):
    python_list.append(number)
    sll.append(number)
    
print(sll)
print(python_list)
# Out:
# Empty lists:
# []
# []
# Lists with one element:
# [1]
# [1]
# Lists with more than one element:
# [1, 2, 3, 4]
# [1, 2, 3, 4]

# %%
help([])
# Out:
# Help on list object:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
#  |  __init__(self, /, *args, **kwargs)
# ...
